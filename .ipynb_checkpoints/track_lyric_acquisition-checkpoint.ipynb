# %% [markdown]
# # Dependencies

# %%
import pandas as pd
import numpy as np
from musixmatch import Musixmatch
from API_Key import api_key
import time
from pprint import pprint

# %%
import sqlalchemy
from sqlalchemy import create_engine, inspect, Column, Integer, Float, String, Sequence, Boolean
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.ext.declarative import declarative_base

# %%
musixmatch = Musixmatch(api_key)

# %% [markdown]
# # Setting up SQLlite

# %%
#Using declarative base
Base = declarative_base()
engine = create_engine('sqlite:///lyrics3.db', echo = False)

# %%
#defining the Tracks table
class Tracks(Base):
    __tablename__ = "tracks"
    
    id = Column(Integer, primary_key=True, nullable = False, unique = True, autoincrement = True)
    album_id = Column(Integer)
    artist_id = Column(Integer)
    artist_name = Column(String)
    explicit = Column(Integer)
    has_lyrics = Column(Integer)
    lyrics_id = Column(Integer)
    track_id = Column(Integer, unique = True)
    track_name = Column(String)

# %%
#defining the Lyrics table
class Lyrics(Base):
    __tablename__ = "lyrics"
    
    id = Column(Integer, primary_key=True, nullable = False, unique = True, autoincrement = True)
    explicit = Column(Integer)
    lyrics_body = Column(String)
    lyrics_id = Column(Integer, unique = True)
    lyrics_language = Column(String)
    lyrics_language_description = Column(String)

# %%
#defining the Artists table
class Artists(Base):
    __tablename__ = "artists"
    
    id = Column(Integer, primary_key=True, nullable = False, unique = True, autoincrement = True)
    artist_id = Column(Integer, unique = True)
    artist_name = Column(String)
    artist_q = Column(String)

# %%
#defining the Albums table
class Albums(Base):
    __tablename__ = "albums"
    
    id = Column(Integer, primary_key=True, nullable = False, unique = True, autoincrement = True)
    artist_id = Column(Integer)
    artist_name = Column(String)
    album_id = Column(Integer, unique = True)
    album_name = Column(String)

# %%
#defining the genres table
class Album_Genres(Base):
    __tablename__ = "album_genres"
    
    id = Column(Integer, primary_key=True, nullable = False, unique = True, autoincrement = True)
    artist_id = Column(Integer)
    artist_name = Column(String)
    album_id = Column(Integer)
    genre = Column(String)
    genre_id = Column(Integer)

# %%
#Creating the table metadata
Base.metadata.create_all(engine)
session = Session(engine)

# %%
#Binding engine to the metadata
meta = sqlalchemy.MetaData()
meta.reflect(bind = engine)

# %% [markdown]
# # MusixMatch API - Finding artists via text search from manually created list

# %%
artists_path = 'artist_names.xlsx'
artists_df = pd.read_excel(artists_path, sheetname = "Sheet1", header = None)
artists = list(artists_df[0].values)

# %%
#Connecting to tracks table
table = sqlalchemy.Table('artists', meta, autoload = True)

# %%
for artist in artists:
    print(f"getting artist names {artist}")
    result = musixmatch.artist_search(q_artist = artist, page = 1, page_size = 100, f_artist_id = '', f_artist_mbid = '')
    print('extracting results')
    artist_list = result['message']['body']['artist_list']
    artists = [artist['artist'] for artist in artist_list]
    print("creating package")
    for item in artists:
        package = {
            'artist_id': item['artist_id'],
            'artist_name': item['artist_name'],
            'artist_q': artist
        }
        try:
            print("writing package to database")
            session.execute(table.insert(), package)
        except:
            next
    print("committing to database")
    session.commit()

# %% [markdown]
# # MusixMatch API - Finding Albums from Artists

# %%
artists = pd.read_sql('artists', engine)
artists.dropna(inplace = True)
artist_ids = list(artists['artist_id'].values)

# %%
table = sqlalchemy.Table('albums', meta, autoload = True)

# %%
for artist_id in artist_ids:
    print(f"getting albums for artist {artist_id}")
    result = musixmatch.artist_albums_get(artist_id = artist_id, g_album_name = '', page = 1, page_size = 100, s_release_date = '')
    print("extracting the album_list")
    album_list = result['message']['body']['album_list']
    print("extracting individual albums")
    albums = [album['album'] for album in album_list]
    print("iterating through the list of albums")
    for item in albums:
        print("creating the package")
        package = {
            'album_id': item['album_id'],
            'album_name': item['album_name'],
            'artist_id': item['artist_id'],
            'artist_name': item['artist_name']
        }
        try:
            print("writing to the database")
            session.execute(table.insert(), package)
        except:
            next
    print("comitting to the database")
    session.commit()

# %% [markdown]
# # MusixMatch API - Scraping Tracks From Charts

# %%
#Connecting to tracks table
table = sqlalchemy.Table('tracks', meta, autoload = True)

# %%
country_codes = ['AU', 'CA', 'IE', 'IM', 'NZ', 'GB', 'US']

# %%
country_count = 1
for country in country_codes:
    
    print(f"Attempting country {country_count} for {country}")
    
    page_count = 1

    while page_count < 5:
        print(f"calling api attempt {page_count} for {country}")
        result = musixmatch.chart_tracks_get(page_count, 100, f_has_lyrics = True)
        tracks = result['message']['body']['track_list']
        track_list = [track['track'] for track in tracks]
        print(f"track list is {len(track_list)}")
        for track in track_list:
            package = {
                'album_id': track['album_id'],
                'artist_id': track['artist_id'],
                'artist_name': track['artist_name'],
                'explicit': track['explicit'],
                'has_lyrics': track['has_lyrics'],
                'lyrics_id': track['lyrics_id'],
                'track_id': track['track_id'],
                'track_name': track['track_name']
            }
            print(package['track_name'])
            print("writing to database")
            try:
                session.execute(table.insert(), package)
            except:
                next
        page_count += 1
        time.sleep(1)
        session.commit()
    
    country_count += 1

# %% [markdown]
# # MusixMatch API - finding tracks from albums

# %% [markdown]
# ## Starting point is the tracks data from the charts

# %%
tracks = pd.read_sql_table('tracks', engine, index_col = "id", coerce_float = False)

# %%
album_ids = tracks['album_id'].values

# %%
#Connecting to tracks table
table = sqlalchemy.Table('tracks', meta, autoload = True)

# %%
album_count = 1

for album_id in album_ids:
    print(f"getting result {album_count} for {album_id}")
    result = musixmatch.album_tracks_get(album_id = album_id, album_mbid = "", page = 1, page_size = 100)
    print(f"getting track_list for {album_id}")
    album = result['message']['body']['track_list']
    print("creating track list")
    track_list = [track['track'] for track in album]
    track_count = 1
    print(f"Iterating through tracks in album")
    for track in track_list:
        print(f"track is {track['track_id']}")
        package = {
                'album_id': int(track['album_id']),
                'artist_id': int(track['artist_id']),
                'artist_name': track['artist_name'],
                'explicit': int(track['explicit']),
                'has_lyrics': int(track['has_lyrics']),
                'lyrics_id': int(track['lyrics_id']),
                'track_id': int(track['track_id']),
                'track_name': track['track_name']
            }
        print(package['track_name'])
        print("writing to database")
        try:
            session.execute(table.insert(), package)
        except:
            print("writing to database failed")
            next
        print("committing files to database")
        session.commit()
    album_count += 1

# %% [markdown]
# ## Starting point is the album's data

# %%
albums = pd.read_sql_table('albums', engine, index_col = "id", coerce_float = False)
albums = albums.iloc[647:]
album_ids = list(albums['album_id'].values)

# %%
#Connecting to tracks table
table = sqlalchemy.Table('tracks', meta, autoload = True)

# %%
album_count = 1

for album_id in album_ids:
    print(f"getting result {album_count} for {album_id}")
    result = musixmatch.album_tracks_get(album_id = album_id, album_mbid = "", page = 1, page_size = 100)
    print(f"getting track_list for {album_id}")
    album = result['message']['body']['track_list']
    print("creating track list")
    track_list = [track['track'] for track in album]
    track_count = 1
    print(f"Iterating through tracks in album")
    for track in track_list:
        print(f"track is {track['track_id']}")
        package = {
                'album_id': int(track['album_id']),
                'artist_id': int(track['artist_id']),
                'artist_name': track['artist_name'],
                'explicit': int(track['explicit']),
                'has_lyrics': int(track['has_lyrics']),
                'lyrics_id': int(track['lyrics_id']),
                'track_id': int(track['track_id']),
                'track_name': track['track_name']
            }
        print(package['track_name'])
        print("writing to database")
        try:
            session.execute(table.insert(), package)
        except:
            print("writing to database failed")
            next
        print("committing files to database")
        session.commit()
    album_count += 1

# %% [markdown]
# ## MusixMatch API - Scraping Lyrics from the Albums Data

# %%
#Connecting to lyrics table
table = sqlalchemy.Table('lyrics', meta, autoload = True)

# %%
tracks = pd.read_sql('tracks', engine, index_col = "id")
track_ids = tracks['track_id'].values

# %%
count = 1
for track in track_ids:
    print(f"calling API attempt {count} for track_id# {track}")
    print(f"track data type is {type(track)}")
    lyrics = musixmatch.track_lyrics_get(track)
    print("pulling out lyrics package")
    lyrics_package = lyrics['message']['body']['lyrics']
    print("pulling out package to insert into SQL database")
    package = {
        "explicit": lyrics_package['explicit'],
        "lyrics_body": lyrics_package["lyrics_body"][:-69],
        "lyrics_id": lyrics_package['lyrics_id'],
        "lyrics_language": lyrics_package['lyrics_language'],
        "lyrics_language_description": lyrics_package['lyrics_language_description'],
        "updated_time": lyrics_package['updated_time']
    }
    
    print(package['lyrics_body'][:10])
    print("writing to database")
    try:
        session.execute(table.insert(), package)
    except:
        next
    print("committing files to database")
    session.commit()
    count += 1

# %% [markdown]
# # Acquiring Genre from Album

# %%
#Connecting to lyrics table
table = sqlalchemy.Table('album_genres', meta, autoload = True)

# %%
albums = pd.read_sql_table('tracks', engine, index_col = "id", coerce_float = False)
album_ids = list(albums['album_id'].values)

# %%
len(album_ids)
# Out:
# 6035

# %%
album_array = np.array(album_ids)

# %%
album_unique = np.unique(album_array)
len(album_unique)
# Out:
# 598

# %%
album_unique[1]
# Out:
# 10268810

# %%
import pprint
data = musixmatch.album_get(album_id=album_unique[5])
pprint.pprint(data)
# Out:
# {'message': {'body': {'album': {'album_copyright': '',
#                                 'album_coverart_100x100': 'http://s.mxmcdn.net/images-storage/albums/nocover.png',
#                                 'album_coverart_350x350': '',
#                                 'album_coverart_500x500': '',
#                                 'album_coverart_800x800': '',
#                                 'album_edit_url': 'https://www.musixmatch.com/album/Led-Zeppelin/Led-Zeppelin-III?utm_source=application&utm_campaign=api&utm_medium=George+Washington+University%3A1409617864811',
#                                 'album_id': 10276578,
#                                 'album_label': '',
#                                 'album_mbid': '7aadcfa2-df82-480e-8d2d-7ec4d0b41172',
#                                 'album_name': 'Led Zeppelin III',
#                                 'album_pline': '',
#                                 'album_rating': 100,
#                                 'album_release_date': '2012-11-28',
#                                 'album_release_type': 'Compilation',
#                                 'album_track_count': 20,
#                                 'album_vanity_id': 'Led-Zeppelin/Led-Zeppelin-III',
#                                 'artist_id': 226,
#                                 'artist_name': 'Led Zeppelin',
#                                 'primary_genres': {'music_genre_list': []},
#                                 'restricted': 0,
#                                 'secondary_genres': {'music_genre_list': []},
#                                 'updated_time': '2016-09-19T08:21:12Z'}},
#              'header': {'execute_time': 0.0018370151519775,
#                         'status_code': 200}}}

# %%
find = data['message']['body']['album']['primary_genres']['music_genre_list']
pprint.pprint(find)
# Out:
# []

# %%
find2 = data['message']['body']['album']['album_name']
pprint.pprint(find2)
# Out:
# 'Hell Awaits'

# %%
genre_dic = {}
for id in album_unique:
    
    result = musixmatch.album_get(album_id=id)
    album = result['message']['body']['album']['album_name']
    print(f'the album is {album}')
    try:
        genre = result['message']['body']['album']['primary_genres']['music_genre_list'][0]['music_genre']['music_genre_name']
        #genre_list = [genre['music_genre'] for genre in genres]
        print(f'the album genre is {genre}')
    except IndexError:
        pass
    try:
        genre = result['message']['body']['album']['secondary_genres']['music_genre_list'][0]['music_genre']['music_genre_name']
        print(f'the album genre is {genre}')
    except IndexError:
        genre="NA"
    genre_dic[f'{album}'] = genre
# Out:
# the album is Led Zeppelin
# the album is Hell Awaits
# the album genre is Rock
# the album is Show No Mercy
# the album genre is Rock
# the album is ...And Justice for All
# the album genre is Rock
# the album is Houses of the Holy
# the album is Led Zeppelin III
# the album is Metallica
# the album is Divine Intervention
# the album genre is Rock
# the album genre is Alternative
# the album is Pinkerton
# the album genre is Rock
# the album is Led Zeppelin II
# the album is Physical Graffiti
# the album is In Through the Out Door
# the album is Reign in Blood
# the album is Seasons In the Abyss
# the album genre is Rock
# the album is Diabolus In Musica
# the album genre is Rock
# the album is God Hates Us All
# the album genre is Hard Rock
# the album is Diabolus in Musica
# the album is Weezer
# the album is South of Heaven
# the album is Weezer
# the album is Reign In Blood
# the album genre is Heavy Metal
# the album is Third Eye Open: The String Quartet Tribute to Tool
# the album is Undisputed Attitude
# the album genre is Rock
# the album is Metallica
# the album is Maladroit
# the album is Undisputed Attitude
# the album is Maladroit
# the album is El Scorcho
# the album is …and Justice for All
# the album is Weezer
# the album genre is Rock
# the album is Show No Mercy
# the album is Show No Mercy
# the album is Seasons in the Abyss
# the album is God Hates Us All
# the album is Endless Flight
# the album is Maladroit & B Sides
# the album is The Very Best of Leo Sayer
# the album is Hell Awaits
# the album is The String Quartet Tribute To Coldplay
# the album is Seasons in the Abyss / Reign in Blood
# the album is God Hates Us All
# the album is Diabolus in Musica
# the album is The Very Best of Leo Sayer
# the album is Show No Mercy
# the album is Undisputed Attitude
# the album is ABBA
# the album is The Very Best of Leo Sayer
# the album is All the Best
# the album is All the Best
# the album is When I Need You '96
# the album is Endless Journey the Essential
# the album is Make Believe
# the album is Washington DC Demo
# the album is Make Believe
# the album is Make Believe
# the album is 20 Greatest Hits
# the album is Maladroit
# the album genre is Rock
# the album is Love Collection
# the album is God Hates Us All
# the album is The Show Must Go on: The Leo Sayer Anthology
# the album is Hell Awaits
# the album is Photograph
# the album is Just a Boy
# the album is At His Very Best
# the album is 20 Great Love Songs
# the album is Silverbird
# the album is Christ Illusion
# the album is ...And Justice For All
# the album genre is Rock
# the album is Voice in My Head
# the album is Christ Illusion
# the album is Cool Touch
# the album is World Radio
# the album is Silverbird
# the album is The Collection
# the album is The Best of Leo Sayer
# the album is Show No Mercy
# the album is Christ Illusion
# the album is Show No Mercy
# the album is Seasons in the Abyss
# the album is Undisputed Attitude
# the album is Weezer
# the album is Weezer
# the album genre is Alternative
# the album is Weezer
# the album genre is World
# the album is Weezer
# the album is Weezer
# the album is Weezer
# the album is We Are All on Drugs
# the album is The Show Must Go On
# the album is One Man Band
# the album is Weezer
# the album is Weezer
# the album is Weezer
# the album is Weezer
# the album is El Scorcho
# the album is Living In a Fantasy
# the album genre is Pop
# the album genre is Rock
# the album is Just a Boy
# the album is Another Year
# the album is Endless Flight
# the album is Thunder in My Heart
# the album is Leo Sayer
# the album is Metallica
# the album genre is Rock
# the album genre is Pop
# the album is Seasons in the Abyss
# the album is Party In the U.S.A.
# the album genre is Pop
# the album is …and Justice for All
# the album is Raditude
# the album is World Painted Blood
# the album genre is Heavy Metal
# the album is Raditude
# the album is Raditude
# the album is Have You Ever Been In Love
# the album genre is Pop
# the album genre is Rock
# the album is Raditude
# the album is Weezer
# the album genre is Rock
# the album genre is Pop
# the album is The Twilight Saga: Breaking Dawn, Pt. 1 (Original Motion Picture Soundtrack) [Deluxe Version]
# the album genre is Soundtrack
# the album is Why Is Everybody Going Home
# the album is Memories
# the album genre is Alternative
# the album is Hurley
# the album is Hurley
# the album genre is Alternative
# the album is Pinkerton
# the album is Led Zeppelin III
# the album is Led Zeppelin
# the album is Led Zeppelin II
# the album is Reign in Blood
# the album is Reign in Blood
# the album is Metallica
# the album is Diabolus in Musica
# the album is God Hates Us All
# the album is Reign in Blood
# the album is ...And Justice for All
# the album genre is Heavy Metal
# the album is Metallica
# the album genre is Rock
# the album is Christ Illusion
# the album genre is Heavy Metal
# the album is Reign in Blood
# the album is Metallica
# the album is Metallica
# the album is Houses of the Holy
# the album is Metallica
# the album genre is Rock
# the album is Seasons in the Abyss
# the album is Seasons In the Abyss
# the album genre is Heavy Metal
# the album is Weezer
# the album is Seasons in the Abyss
# the album is Diabolus In Musica
# the album genre is Heavy Metal
# the album is Physical Graffiti
# the album is Physical Graffiti
# the album is Show No Mercy
# the album is Hell Awaits
# the album is Reign in Blood
# the album is Hell Awaits
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Led Zeppelin III
# the album is …and Justice for All
# the album is In Through The Out Door
# the album is Led Zeppelin III
# the album is Led Zeppelin
# the album is Weezer
# the album is Make Believe
# the album genre is Alternative
# the album genre is Rock
# the album is Led Zeppelin
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Houses of the Holy
# the album is Physical Graffiti
# the album is In Through the Out Door
# the album is Led Zeppelin II
# the album is God Hates Us All
# the album is In Through the Out Door
# the album is Led Zeppelin II
# the album is Physical Graffiti
# the album is Weezer
# the album is Houses of the Holy
# the album is Hell Awaits
# the album is Show No Mercy
# the album is South of Heaven
# the album genre is Heavy Metal
# the album is Led Zeppelin III
# the album is Led Zeppelin
# the album is Silverbird
# the album is Houses of the Holy
# the album is In Through the Out Door
# the album is Seasons in the Abyss
# the album is Metallica
# the album genre is Rock
# the album is Metallica
# the album is Led Zeppelin
# the album is Houses of the Holy
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is …and Justice for All
# the album is Led Zeppelin
# the album is Led Zeppelin II
# the album is Led Zeppelin
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Diabolus in Musica
# the album is Endless Flight
# the album is Led Zeppelin
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is …and Justice for All
# the album is Divine Intervention
# the album genre is Heavy Metal
# the album is Led Zeppelin
# the album is Led Zeppelin III
# the album is Houses of the Holy
# the album is Raditude
# the album is Raditude
# the album is Weezer
# the album is Weezer
# the album is Weezer
# the album is World Painted Blood
# the album is World Painted Blood
# the album is Show No Mercy
# the album is Hell Awaits
# the album is Houses Of The Holy
# the album is Houses of the Holy
# the album is Weezer
# the album is Reign in Blood
# the album is …and Justice for All
# the album is VSQ Performs Lady Gaga
# the album genre is Classical Crossover
# the album genre is Pop
# the album is Led Zeppelin
# the album is Led Zeppelin III
# the album is Hell Awaits
# the album is Hurley
# the album is The Essential John Denver
# the album is …and Justice for All
# the album is South of Heaven
# the album genre is Heavy Metal
# the album is Seasons in the Abyss
# the album is Divine Intervention
# the album genre is Heavy Metal
# the album is Seasons in the Abyss
# the album is South of Heaven
# the album is Metallica
# the album is Physical Graffiti
# the album is Maladroit
# the album is Weezer
# the album is Gold: Greatest Hits
# the album is Led Zeppelin
# the album is Show No Mercy
# the album is Reign in Blood
# the album is Seasons in the Abyss
# the album is Pinkerton
# the album is You Make Me Feel Like Dancing And Other Hits
# the album is Christ Illusion
# the album is Here
# the album genre is Rock
# the album is Thunder In My Heart
# the album is Metallica
# the album genre is Rock
# the album is Reign in Blood
# the album is World Painted Blood
# the album is Show No Mercy
# the album is When I Need You / You Make Me Feel Like Dancing
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Houses of the Holy
# the album is Physical Graffiti
# the album is Vitamin String Quartet Performs Muse
# the album is Pinkerton
# the album is Physical Graffiti
# the album is Led Zeppelin II
# the album is Led Zeppelin II
# the album is Seasons in the Abyss
# the album is Undisputed Attitude
# the album is Undisputed Attitude
# the album genre is Heavy Metal
# the album is South of Heaven
# the album is Leo Sayer
# the album is Physical Graffiti
# the album is Divine Intervention
# the album is Leo Sayer
# the album is South of Heaven
# the album is Show No Mercy
# the album is Led Zeppelin
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Led Zeppelin
# the album is Just a Boy
# the album is Reign in Blood
# the album is Seasons in the Abyss
# the album is More Than I Can Say / Only Fooling
# the album is Live In Glasgow
# the album is Reign in Blood
# the album is God Hates Us All
# the album is Physical Graffiti
# the album is Christ Illusion
# the album is The Greatest Hits
# the album is God Hates Us All
# the album is The Kitchen Tapes
# the album is Led Zeppelin
# the album is Weezer
# the album is Maladroit
# the album genre is Rock
# the album is (If You’re Wondering If I Want You To) I Want You To
# the album is Weezer
# the album is Undisputed Attitude
# the album genre is Heavy Metal
# the album is Led Zeppelin II
# the album is South of Heaven
# the album is Led Zeppelin III
# the album is Led Zeppelin II
# the album is Houses of the Holy
# the album is Physical Graffiti
# the album is Led Zeppelin
# the album is Physical Graffiti
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Physical Graffiti
# the album is Led Zeppelin
# the album is Led Zeppelin III
# the album is Led Zeppelin III
# the album is Houses of the Holy
# the album is Physical Graffiti
# the album is Led Zeppelin II
# the album is Reign in Blood
# the album is True Believers (Deluxe Version)
# the album genre is Country
# the album genre is Contemporary Country
# the album is VSQ Performs the Hits of 2013, Vol. 1
# the album genre is Rock
# the album genre is Pop
# the album is Almost There
# the album genre is Christian & Gospel
# the album is The Foundation (Deluxe Version)
# the album genre is Country
# the album is Weezer - Deluxe Edition
# the album genre is Rock
# the album is Weezer
# the album genre is Rock
# the album genre is Alternative
# the album is Buffy the Vampire Slayer (The Album)
# the album genre is Pop
# the album is Once More With Feeling (Episode Soundtrack)
# the album genre is Soundtrack
# the album is Maladroit
# the album is Making Noise
# the album genre is Rock
# the album genre is Pop
# the album is El Scorcho
# the album is You Make Me Feel Like Dancing - Live
# the album genre is Rock
# the album is Thunder In My Heart
# the album genre is Pop
# the album genre is Rock
# the album is Big Shiny Tunes 13
# the album genre is Rock
# the album is Pinkerton
# the album genre is Rock
# the album genre is Pop
# the album is Reign In Blood
# the album genre is Rock
# the album is God Hates Us All
# the album genre is Rock
# the album is Christ Illusion
# the album genre is Heavy Metal
# the album is God Hates Us All
# the album genre is Heavy Metal
# the album is Weezer
# the album genre is Alternative
# the album genre is Pop
# the album is Maladroit
# the album genre is Rock
# the album is Make Believe
# the album genre is Alternative
# the album genre is Rock
# the album is Make Believe
# the album genre is Rock
# the album is Weezer
# the album genre is Rock
# the album is Troublemaker
# the album genre is Alternative
# the album genre is Rock
# the album is Troublemaker
# the album genre is World
# the album is (If You're Wondering If I Want You To) I Want You To
# the album genre is Rock
# the album genre is Alternative
# the album is Raditude
# the album genre is Alternative
# the album is Raditude
# the album genre is Alternative
# the album is Pinkerton - Deluxe Edition
# the album genre is Rock
# the album is Raditude
# the album genre is Alternative
# the album is Hurley
# the album genre is Rock
# the album is Another Year
# the album genre is Rock
# the album is Leo Sayer
# the album genre is Rock
# the album is Don't Wait Until Tomorrow
# the album genre is Easy Listening
# the album is The River Sessions
# the album genre is Rock
# the album genre is Pop
# the album is Voices In My Head
# the album genre is Pop
# the album is Leo Sayer: Live In 1975
# the album genre is Pop
# the album is Endless Journey – The Essential Leo Sayer
# the album genre is Pop
# the album genre is Vocal
# the album is Another Year
# the album genre is Pop
# the album genre is Dance
# the album is Endless Flight
# the album genre is Pop
# the album genre is Rock
# the album is Silverbird
# the album genre is Pop
# the album genre is Rock
# the album is Just a Boy
# the album genre is Pop
# the album genre is Rock
# the album is All the Best - The Video Collection
# the album genre is Pop
# the album is Here
# the album genre is Pop
# the album genre is Rock
# the album is Leo Sayer
# the album genre is Pop
# the album is World Radio
# the album genre is Pop
# the album genre is Rock
# the album is World Radio / Have You Ever Been In Love
# the album genre is Pop
# the album genre is Rock
# the album is Leo Sayer
# the album genre is Rock
# the album is Leo Sayer
# the album genre is Pop
# the album genre is Rock
# the album is Living In a Fantasy
# the album genre is Pop
# the album genre is Rock
# the album is Thunder In My Heart + Leo Sayer
# the album genre is Pop
# the album genre is Rock
# the album is Have You Ever Been In Love
# the album genre is Pop
# the album genre is Rock
# the album is Silverbird
# the album genre is Pop
# the album is Leo Sayer
# the album genre is Pop
# the album is Have You Never Been In Love
# the album genre is Pop
# the album is Endless Flight
# the album genre is Pop
# the album is Leo Sayer: The Greatest Hits
# the album genre is Pop
# the album is Living In a Fantasy
# the album genre is Pop
# the album is Make Believe
# the album is Just a Boy
# the album genre is Rock
# the album is Silverbird
# the album genre is Rock
# the album is Endless Flight
# the album genre is Rock
# the album is Have You Ever Been In Love
# the album genre is Rock
# the album is Just a Box - The Complete Studio Recordings 1971 - 2006
# the album genre is Pop
# the album is The Show Must Go On: The Leo Sayer Anthology
# the album genre is Rock
# the album is The String Quartet Tribute to Coldplay
# the album genre is Classical
# the album genre is Pop
# the album is The String Quartet Tribute to The Smiths
# the album genre is Rock
# the album genre is Alternative
# the album is Vitamin String Quartet: The Tribute to Guitar Hero
# the album genre is Classical
# the album is VSQ Film School - Cult Classics and Indie Favs
# the album genre is Rock
# the album genre is Soundtrack
# the album is G I R L
# the album genre is Pop
# the album is Once More, With Feeling
# the album genre is Soundtrack
# the album is Christ Illusion
# the album genre is Heavy Metal
# the album is World Painted Blood
# the album genre is Heavy Metal
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Led Zeppelin
# the album is x
# the album is Make Believe
# the album genre is Rock
# the album is Back to the Shack
# the album genre is Pop
# the album is Back to the Shack
# the album is Led Zeppelin
# the album is 1989
# the album genre is Pop
# the album is Everything Will Be Alright in the End
# the album is Everything Will Be Alright In the End
# the album genre is Alternative
# the album is Everything Will Be Alright in the End
# the album is You Make Me Feel Like Dancing Live with Leo Sayer
# the album genre is Rock
# the album is Everything Will Be Alright in the End
# the album is Houses of the Holy
# the album is Houses of the Holy
# the album is Love In the Future
# the album genre is R&B/Soul
# the album is Everything Will Be Alright In the End
# the album genre is Alternative
# the album is The Platinum Collection (Greatest Hits I, II & III)
# the album genre is Rock
# the album is More Than I Can Say (Best Gold Edition) [+ Bonus Tracks] [Remastered]
# the album genre is Pop
# the album is Uptown Special
# the album is Live in 1975
# the album genre is Disco
# the album is Hurley
# the album is Led Zeppelin II
# the album is Led Zeppelin III
# the album is Led Zeppelin
# the album is Show No Mercy
# the album is Led Zeppelin
# the album is Physical Graffiti
# the album is Поет Лео Сейер
# the album is Led Zeppelin III
# the album is Led Zeppelin IV
# the album is Led Zeppelin IV
# the album is Physical Graffiti
# the album is Traveller
# the album genre is Country
# the album is Led Zeppelin
# the album is The String Quartet Tribute to the Smiths
# the album genre is Alternative
# the album genre is Adult Alternative
# the album is The String Quartet Tribute To Radiohead: Enigmatic
# the album genre is Alternative
# the album genre is Rock
# the album is Repentless
# the album genre is Heavy Metal
# the album is Immortalized (Deluxe Version)
# the album genre is Rock
# the album is Repentless
# the album genre is Heavy Metal
# the album is Thank God For Girls
# the album genre is Alternative
# the album is Do You Wanna Get High?
# the album genre is Alternative
# the album is Night Visions
# the album is Christ Illusion
# the album is A Salute To Led Zeppelin
# the album is News Of The World
# the album is Waterloo (Deluxe Edition)
# the album is Show No Mercy
# the album is Hurley
# the album is Raditude
# the album is Raditude
# the album is Weezer
# the album is Make Believe
# the album is Make Believe
# the album is Pinkerton - Deluxe Edition
# the album is Weezer
# the album genre is Rock
# the album is Toto IV
# the album is Toto IV (Alben für die Ewigkeit)
# the album is Another Year
# the album is VSQ Performs the Hits of 2013 Vol. 2
# the album is A Perfect Ten - 1977
# the album is More Than I Can Say (Best Gold Edition) [+ Bonus Tracks]
# the album is The Greatest Hits
# the album is Leo Sayer
# the album is Live in 1975
# the album is Live in Glasgow
# the album is Very Best Of Leo Sayer
# the album is Here
# the album is Leo Sayer
# the album is The Show Must Go On: The Leo Sayer Anthology
# the album is Have You Ever Been In Love
# the album is World Radio
# the album is Brett Young
# the album genre is Country
# the album is Hero
# the album genre is Country
# the album is I Love the USA
# the album genre is Alternative
# the album is Make Believe
# the album genre is Rock
# the album is Raditude
# the album genre is Rock
# the album is Trolls (Original Motion Picture Soundtrack)
# the album genre is Children's Music
# the album genre is Soundtrack
# the album is Kane Brown
# the album genre is Country
# the album is Stoney (Deluxe)
# the album genre is Hip Hop/Rap
# the album is 24K Magic
# the album is ÷ (Deluxe)
# the album genre is Pop
# the album genre is Singer/Songwriter
# the album is Brett Young
# the album genre is Country
# the album is Body Like a Back Road
# the album genre is Country
# the album is Lifer
# the album genre is Christian & Gospel
# the album is Memories...Do Not Open
# the album genre is Dance
# the album is Ready
# the album genre is R&B/Soul
# the album is Feels Like Summer
# the album genre is Alternative
# the album is From A Room: Volume 1
# the album genre is Country
# the album is Despacito Feat. Justin Bieber (Remix)
# the album is Dua Lipa (Deluxe)
# the album genre is Pop
# the album is This One's for You
# the album genre is Country
# the album is Woodstock
# the album genre is Alternative
# the album is I Like Me Better
# the album genre is Pop
# the album is Wonder
# the album genre is Christian & Gospel
# the album is Sacred Hearts Club
# the album genre is Alternative
# the album is Dylan Scott (Deluxe Edition)
# the album genre is Country
# the album is Nevermind
# the album genre is Pop
# the album is Happy Endings
# the album genre is Country
# the album is Kiss Somebody
# the album genre is Country
# the album is Songs from Season Two
# the album genre is Alternative
# the album genre is Singer/Songwriter
# the album is Life Changes
# the album genre is Country
# the album is Pompeii Sessions
# the album genre is Rock
# the album is All Your Fault: Pt. 2
# the album is Unapologetically
# the album genre is Country
# the album is Freudian
# the album genre is R&B/Soul
# the album is EVERYBODY
# the album genre is Country
# the album is Pacific Daydream
# the album genre is Alternative
# the album is Tell Me You Love Me
# the album genre is Pop
# the album is GEMINI
# the album genre is Hip Hop/Rap
# the album is reputation
# the album genre is Pop
# the album is Drew Barrymore
# the album genre is Hip Hop/Rap
# the album is Perception
# the album genre is Hip Hop/Rap
# the album is Kane Brown (Deluxe Edition)
# the album genre is Country
# the album is Everything I Could Never Say...
# the album genre is Alternative
# the album is Every Little Thing
# the album genre is Country
# the album is What Makes You Country
# the album genre is Country
# the album is Voicenotes
# the album genre is Pop
# the album is From A Room: Volume 2
# the album genre is Country
# the album is Tell Me You Love Me
# the album genre is Pop
# the album is Reckless Love
# the album genre is Christian & Gospel
# the album genre is Praise & Worship
# the album is The Greatest Showman (Original Motion Picture Soundtrack)
# the album genre is Soundtrack
# the album is Hallelujah Nights
# the album genre is Country
# the album is Camila
# the album genre is Pop
# the album is Perfect Symphony
# the album genre is Classical Crossover
# the album genre is Singer/Songwriter
# the album is The Champion
# the album genre is Pop
# the album is Seasons Change
# the album genre is Country
# the album is Love, Simon (Original Motion Picture Soundtrack)
# the album genre is Soundtrack
# the album is Zombie
# the album genre is Heavy Metal
# the album genre is Alternative
# the album is The Middle
# the album genre is Dance
# the album is Dream It Possible
# the album is Evolve
# the album genre is Alternative
# the album is Mitchell Tenpenny
# the album is No Zip Code
# the album genre is Country
# the album is Speak Your Mind
# the album genre is Pop
# the album genre is Electronic
# the album is There Is More (Live)
# the album genre is Christian & Gospel
# the album is ?
# the album genre is Pop
# the album is Freaky Friday (feat. Chris Brown)
# the album is Burn the House Down
# the album genre is Pop
# the album is Rearview Town
# the album genre is Country
# the album is Remind Me to Forget
# the album genre is Dance
# the album is Pray For The Wicked
# the album genre is Alternative
# the album is Invasion of Privacy
# the album is One Kiss
# the album genre is Dance
# the album is Graffiti U
# the album genre is Country
# the album is Nice For What
# the album genre is Hip Hop/Rap
# the album is I Was Jack (You Were Diane)
# the album genre is Country
# the album is Te Boté (Remix)
# the album genre is Latin Urban
# the album is Cry Pretty
# the album genre is Country
# the album is COSMIC
# the album genre is Pop
# the album is Youngblood (Deluxe)
# the album genre is Pop
# the album is Bigger
# the album genre is Country
# the album is Expectations
# the album genre is Pop
# the album is The Mountain
# the album genre is Country
# the album is If I Know Me
# the album genre is Country
# the album is beerbongs & bentleys
# the album genre is Hip Hop/Rap
# the album is No Tears Left to Cry
# the album genre is Pop
# the album is lovely
# the album genre is Alternative
# the album is Shawn Mendes
# the album genre is Pop
# the album is Have It All
# the album genre is Pop
# the album is This One's for You Too (Deluxe Edition)
# the album genre is Country
# the album is This Is America
# the album genre is Hip Hop/Rap
# the album is New Light
# the album genre is Pop
# the album is Mamma Mia! Here We Go Again (Original Motion Picture Soundtrack)
# the album genre is Soundtrack
# the album is 13 Reasons Why: Season 2 (Music from the Original TV Series)
# the album genre is Soundtrack
# the album is Taste (feat. Offset)
# the album is Don't Go Breaking My Heart
# the album genre is Pop
# the album is Harder Than Ever
# the album genre is Hip Hop/Rap
# the album is Solo (feat. Demi Lovato)
# the album is Jackie Chan
# the album genre is Dance
# the album is Dinero
# the album genre is Pop
# the album is Dan + Shay
# the album genre is Country
# the album is Goodbye & Good Riddance
# the album genre is Hip Hop/Rap
# the album is Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj
# the album is Girls Like You (feat. Cardi B)
# the album is Florida Georgia Line
# the album genre is Country
# the album is Lose It
# the album is Queen
# the album genre is Hip Hop/Rap
# the album is The Breakup Song
# the album is EVERYTHING IS LOVE
# the album genre is Hip Hop/Rap
# the album is Born to Be Yours
# the album genre is Dance
# the album is Laps Around the Sun
# the album genre is Country
# the album is Lifers
# the album genre is Country
# the album is Songs for the Saints
# the album genre is Country
# the album is NOVA
# the album genre is Electronic
# the album is Sweetener
# the album genre is Pop
# the album is Sober
# the album genre is Pop
# the album is TREAT MYSELF
# the album genre is Pop
# the album is Connection
# the album genre is Pop
# the album is Red Pill Blues (Deluxe)
# the album genre is Pop
# the album is Scorpion
# the album genre is Hip Hop/Rap
# the album is Burn The Ships
# the album genre is Christian & Gospel
# the album is Smile Bitch
# the album genre is Hip Hop/Rap
# the album is Jumpsuit / Nico And The Niners
# the album genre is Alternative
# the album is Summertime Magic
# the album is Mamma Mia! Here We Go Again (Original Motion Picture Soundtrack)
# the album is Eastside
# the album genre is Pop
# the album is Desperate Man
# the album genre is Country
# the album is All of It
# the album genre is Country
# the album is Look Up Child
# the album genre is Christian & Gospel
# the album is Natural
# the album genre is Alternative
# the album is When The Curtain Falls
# the album is Level Up
# the album is you should see me in a crown
# the album is Happy Now
# the album genre is Dance
# the album is FEFE (feat. Nicki Minaj & Murda Beatz)
# the album is Attention
# the album is Queen Naija
# the album genre is R&B/Soul
# the album is SWISH
# the album genre is Hip Hop/Rap
# the album is I Don't Want: The Gold Fire Sessions
# the album is Throw A Fit
# the album is Don't Leave Me Alone (feat. Anne-Marie)
# the album is One Day (feat. Ryan Tedder)
# the album is I Don't Dance (Without You) [feat. Konshens]
# the album is Wicked Heart
# the album is Candlelight
# the album is Hot Summer
# the album is Songs for the Saints
# the album is Side Effects
# the album genre is Dance
# the album is Level Up [Remix]
# the album genre is R&B/Soul
# the album is No Brainer

# %%
# Out:
# []

# %%
album_count = 1

for album_id in album_unique:
    print(f"getting result {album_count} for {album_id}")
    result = musixmatch.album_get(album_id = album_id)
    print(f"getting information for {album_id}")
    album = result['message']['body']['album']
    print("creating genre list")
    genres = result['message']['body']['album']['primary_genres']['music_genre_list']
    genre_list = [genre['music_genre'] for genre in genres]
    print(f"Iterating through album genres")
    for genre in track_list:
        package = {
                'album_id': int(album['album_id']),
                'artist_id': int(album['artist_id']),
                'artist_name': album['artist_name'],
                'genre': genre['music_genre_name'],
                'genre_id': genre['music_genre_id']
                
            }
        print(package['album_id'])
        print("writing to database")
        try:
            session.execute(table.insert(), package)
        except:
            print("writing to database failed")
            next
        print("committing files to database")
        session.commit()
    album_count += 1
